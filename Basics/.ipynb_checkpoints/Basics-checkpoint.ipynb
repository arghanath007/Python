# %% [markdown]
# # Basics

# %% [markdown]
# ## Variables

# %%
can = "soda"

# %%
can
# Out:
# 'soda'

# %%
can = "beans"

# %%
can
# Out:
# 'beans'

# %%
type(can)
# Out:
# str

# %%
first_name = "John"
last_name = "Wick"

# %%
type(last_name)
# Out:
# str

# %%
pizza = 100
pizza
# Out:
# 100

# %%
type(pizza)
# Out:
# int

# %%
samosa = 20.5
type(samosa)
# Out:
# float

# %%
ice_cream = 40
ice_cream
# Out:
# 40

# %%
total = pizza + samosa + ice_cream
total
# Out:
# 160.5

# %%
type(total)
# Out:
# float

# %%
learn_python = True
learn_fortran = False

# %%
type(learn_fortran)
# Out:
# bool

# %%
foo = 'jalebi'
foo
# Out:
# 'jalebi'

# %%
bar = foo
bar
# Out:
# 'jalebi'

# %%
id(foo)
# Out:
# 2245431262928

# %%
id(bar)
# Out:
# 2245431262928

# %%
bar = "samosa"
bar
# Out:
# 'samosa'

# %%
id(foo)
# Out:
# 2245431262928

# %%
id(bar)
# Out:
# 2245432492512

# %%
first_name
# Out:
# 'John'

# %%
firstname_ = first_name
firstname_
# Out:
# 'John'

# %% [markdown]
# ## Variable Exercise
#
# ![image.png](attachment:1c7b1af5-6e7c-4950-9dcd-aba32d05f876.png)
# * Link -> https://codebasics.io/courses/python-for-beginner-and-intermediate-learners/lecture/828

# %%
pi = 22/7
type(pi)
# Out:
# float

# %%
## for = 4 ## This is giving error because for is a reserved keyword in python

# %% [markdown]
# ![image.png](attachment:a8e23a46-c5c9-4ec0-8fcc-dff2af1529aa.png)

# %%
for1 = 4
for1
# Out:
# 4

# %%
P = 100000
R = 5.2
T = 20
SI = (P * R * T)/100

# %%
print(SI)
# Out:
# 104000.0

# %%
type(SI)
# Out:
# float

# %% [markdown]
# ## Numbers

# %%
base = 20
height = 3

# %%
Area = 1/2 * base * height
Area
# Out:
# 30.0

# %%
base1 = 20.5
height1 = 6

# %%
Area1 = 1/2 * base1 * height1
Area1
# Out:
# 61.5

# %%
type(Area)
# Out:
# float

# %%
type(Area1)
# Out:
# float

# %%
10/3
# Out:
# 3.3333333333333335

# %%
10//3
# Out:
# 3

# %%
15%2
# Out:
# 1

# %%
3 ** 3 ## Power Calculation
# Out:
# 27

# %%
3 * 3 * 3
# Out:
# 27

# %%
2 ** 10 ## Power Calculation
# Out:
# 1024

# %%
20 + 3 * 4
# Out:
# 32

# %%
(20 + 3) * 3
# Out:
# 69

# %% [markdown]
# ### Scientific Calculations
#
# ![image](https://github.com/arghanath007/Python/assets/54589605/f590d7c1-e5c7-4537-ae33-5f5c7fdaed3b)
# ![image](https://github.com/arghanath007/Python/assets/54589605/98af1f2f-232a-4d5f-ad9a-d4d3896061a4)
# ![image](https://github.com/arghanath007/Python/assets/54589605/89055766-3038-4b37-901b-ed4caf12e0dc)

# %%
foo = 2.3e6

# %%
foo
# Out:
# 2300000.0

# %%
bar = 2.3e-6

# %%
bar
# Out:
# 2.3e-06

# %%
bar1 = 2.3e-2
bar1
# Out:
# 0.023

# %%
Food = 200.5
Internet = 590
Transport = 200.3

# %%
Total = Food + Internet + Transport
Total
# Out:
# 990.8

# %%
round(Total)
# Out:
# 991

# %%
income = 10000
expenses = 1000
savings = income - expenses

# %%
savings
# Out:
# 9000

# %% [markdown]
# ![image.png](attachment:5868b33b-0c15-4387-9b92-fef672b3deac.png)
#
# > It is simplying **concatenating/appending** both of the strings together when we do **plus(+)** if two strings together.

# %%
food = "90.5"
internet = "590"

# %%
type(internet)
# Out:
# str

# %%
total = food + internet
total
# Out:
# '90.5590'

# %% [markdown]
# ![image.png](attachment:61823491-6890-4930-ab3e-322dd37910c0.png)

# %%
format(5, 'b') ## Binary Representation of numbers
# Out:
# '101'

# %% [markdown]
# ## Numbers Exercise
#
# ![image.png](attachment:e5b18ea2-dee1-49a0-b12b-96599a1b2cbd.png)
#
# * Link -> https://codebasics.io/courses/python-for-beginner-and-intermediate-learners/lecture/831

# %%
format(145, 'o')
# Out:
# '221'

# %%
r = 84
Area = 22/7 * r * r
Water = Area * 1.4

# %%
print(Area)
# Out:
# 22176.0

# %%
print(Water)
# Out:
# 31046.399999999998

# %%
r = 84
Area = 3.14 * r ** 2 
Water = Area * 1.4

# %%
print(Area)
# Out:
# 22155.84

# %%
Water = Area * 1.4
print(Water)
# Out:
# 31018.176

# %%
D = 490
T = 7 * 60
S = D / T

# %%
T
# Out:
# 420

# %%
print(S)
# Out:
# 1.1666666666666667

# %%
print(round(S))
# Out:
# 1

# %% [markdown]
# ## String

# %%
first = "John"
last = "Wick"

# %%
name = first + " " + last
name
# Out:
# 'John Wick'

# %%
fname = f'{first} {last} is a movie character'
fname
# Out:
# 'John Wick is a movie character'

# %% [markdown]
# ### Example
#
# ![image.png](attachment:3ee8f142-e5d2-42b6-bd79-7799402c8fe4.png)

# %%
name[0:4]
# Out:
# 'John'

# %%
name[4:]
# Out:
# ' Wick'

# %%
name[:4]  ## Positive Indexing
# Out:
# 'John'

# %%
name[:]
# Out:
# 'John Wick'

# %%
name[:-2]  ## Negative Indexing
# Out:
# 'John Wi'

# %%
name[-2:]
# Out:
# 'ck'

# %%
len(name)
# Out:
# 9

# %%
foods = "oats, shake, omlette"
foods
# Out:
# 'oats, shake, omlette'

# %%
'salad' in foods
# Out:
# False

# %%
'oats' in foods
# Out:
# True

# %%
'salad' not in foods  ## Negation
# Out:
# True

# %%
food = 'oats, shake, omlette'
food
# Out:
# 'oats, shake, omlette'

# %%
'salad' in food
# Out:
# False

# %%
"oats" in foods
# Out:
# True

# %%
"salad" not in foods  ## Negation
# Out:
# True

# %%
statement = f"The favourite food of {first} {last}'s is biriyani"
statement
# Out:
# "The favourite food of John Wick's is biriyani"

# %%
statement1 = '''The favourite food of {first} {last}'s is biriyani'''
statement1
# Out:
# "The favourite food of {first} {last}'s is biriyani"

# %%
statement1.replace("of", "off")
# Out:
# "The favourite food off {first} {last}'s is biriyani"

# %%
statement1 ## replace() is not replacing the original statement.
# Out:
# "The favourite food of {first} {last}'s is biriyani"

# %%
dir(statement1)
# Out:
# ['__add__',
#  '__class__',
#  '__contains__',
#  '__delattr__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__getnewargs__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__mod__',
#  '__mul__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__rmod__',
#  '__rmul__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'capitalize',
#  'casefold',
#  'center',
#  'count',
#  'encode',
#  'endswith',
#  'expandtabs',
#  'find',
#  'format',
#  'format_map',
#  'index',
#  'isalnum',
#  'isalpha',
#  'isascii',
#  'isdecimal',
#  'isdigit',
#  'isidentifier',
#  'islower',
#  'isnumeric',
#  'isprintable',
#  'isspace',
#  'istitle',
#  'isupper',
#  'join',
#  'ljust',
#  'lower',
#  'lstrip',
#  'maketrans',
#  'partition',
#  'removeprefix',
# ...

# %%
statement1
# Out:
# "The favourite food of {first} {last}'s is biriyani"

# %%
statement1.upper()
# Out:
# "THE FAVOURITE FOOD OF {FIRST} {LAST}'S IS BIRIYANI"

# %%
statement1.lower()
# Out:
# "the favourite food of {first} {last}'s is biriyani"

# %%
statement1.index('food')
# Out:
# 14

# %%
statement1.index('f')
# Out:
# 4

# %%
statement1.index('i')
# Out:
# 10

# %%
 # statement1.index('z')  This will give an error.
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[165], line 1
# ----> 1 statement1.index('z') ## This will give an error.
#
# ValueError: substring not found

# %% [markdown]
# ![image.png](attachment:1db2ac0c-c66a-4eb7-b8f8-d652495ebcb5.png)

# %%
age = 23

# %%
# statement1 + age # Error
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[167], line 1
# ----> 1 statement1 + age # Error
#
# TypeError: can only concatenate str (not "int") to str

# %% [markdown]
# ![image.png](attachment:6a13dfe1-5c0b-4397-bc27-614e3a7c69dc.png)

# %%
str(age)
# Out:
# '23'

# %%
type(age)
# Out:
# int

# %%
statement1 + " " + str(age)
# Out:
# "The favourite food of {first} {last}'s is biriyani 23"

# %%
f"My age is: {age}"
# Out:
# 'My age is: 23'

# %%
patient_information = f'Name: {first} {last} \nAge: {age} yrs'

# %%
print(patient_information)
# Out:
# Name: John Wick
# Age: 23 yrs

# %%
patient_information # We have to write the variable within print() otherwise the '\n' will not work
# Out:
# 'Name: John Wick \nAge: 23 yrs'

# %%
s = "tab\tbro"
print(s)
# Out:
# tab	bro

# %%
s # We have to write the variable within print() otherwise the '\t' will not work
# Out:
# 'tab\tbro'

# %%
s.upper()
# Out:
# 'TAB\tBRO'

# %%
s.capitalize()
# Out:
# 'Tab\tbro'

# %%
s.title()
# Out:
# 'Tab\tBro'

# %%
s
# Out:
# 'tab\tbro'

# %%
'tab' not in s

# %%
'tab' in s
# Out:
# True

# %% [markdown]
# ## String Exercise

# %%
help(str)
# Out:
# Help on class str in module builtins:
#
# class str(object)
#  |  str(object='') -> str
#  |  str(bytes_or_buffer[, encoding[, errors]]) -> str
#  |
#  |  Create a new string object from the given object. If encoding or
#  |  errors is specified, then the object must expose a data buffer
#  |  that will be decoded using the given encoding and error handler.
#  |  Otherwise, returns the result of object.__str__() (if defined)
#  |  or repr(object).
#  |  encoding defaults to sys.getdefaultencoding().
#  |  errors defaults to 'strict'.
#  |
#  |  Methods defined here:
#  |
#  |  __add__(self, value, /)
#  |      Return self+value.
#  |
#  |  __contains__(self, key, /)
#  |      Return bool(key in self).
#  |
#  |  __eq__(self, value, /)
#  |      Return self==value.
#  |
#  |  __format__(self, format_spec, /)
#  |      Return a formatted version of the string as described by format_spec.
#  |
#  |  __ge__(self, value, /)
#  |      Return self>=value.
#  |
# ...

# %%
help(str)
# Out:
# Help on class str in module builtins:
#
# class str(object)
#  |  str(object='') -> str
#  |  str(bytes_or_buffer[, encoding[, errors]]) -> str
#  |
#  |  Create a new string object from the given object. If encoding or
#  |  errors is specified, then the object must expose a data buffer
#  |  that will be decoded using the given encoding and error handler.
#  |  Otherwise, returns the result of object.__str__() (if defined)
#  |  or repr(object).
#  |  encoding defaults to sys.getdefaultencoding().
#  |  errors defaults to 'strict'.
#  |
#  |  Methods defined here:
#  |
#  |  __add__(self, value, /)
#  |      Return self+value.
#  |
#  |  __contains__(self, key, /)
#  |      Return bool(key in self).
#  |
#  |  __eq__(self, value, /)
#  |      Return self==value.
#  |
#  |  __format__(self, format_spec, /)
#  |      Return a formatted version of the string as described by format_spec.
#  |
#  |  __ge__(self, value, /)
#  |      Return self>=value.
#  |
# ...

# %%
fruits = 6
vegetables = 4
statement = f"I eat {vegetables} vegetables and {fruits} fruits daily"
statement
# Out:
# 'I eat 4 vegetables and 6 fruits daily'

# %%
statement2 = "The Himalayas are one of the youngest mountain ranges on the planet."

# %%
print(statement2[:14])
# Out:
# The Himalayas

# %%
print(statement2[-31: -15])
# Out:
#  mountain ranges

# %%
print(statement2[:14] + statement2[-14:])
# Out:
# The Himalayas on the planet.

# %%
statement3 = statement2[:14]
statement4 = statement2[-14:]
print(statement3 + statement4)
# Out:
# The Himalayas on the planet.

# %%
print(f"{statement3}{statement4}")
# Out:
# The Himalayas on the planet.

# %%
statement5 = "There are 9 planets in the solar system"

# %%
statement5 = statement5.replace('9', '8')
statement5
# Out:
# 'There are 8 planets in the solar system'

# %% [markdown]
# ## Lists

# %%
basket = ["bread", "pasta", "fruits", "veggies"]
basket
# Out:
# ['bread', 'pasta', 'fruits', 'veggies']

# %%
basket[:2]
# Out:
# ['bread', 'pasta']

# %%
basket.append("eggs")
basket
# Out:
# ['bread', 'pasta', 'fruits', 'veggies', 'eggs']

# %%
basket.insert(2, "butter")
basket
# Out:
# ['bread', 'pasta', 'butter', 'fruits', 'veggies', 'eggs']

# %%
basket.remove("pasta")
basket
# Out:
# ['bread', 'butter', 'fruits', 'veggies', 'eggs']

# %%
"bread" not in basket
# Out:
# False

# %%
expenses = [23,343,231,465,8798,3,89]
expenses
# Out:
# [23, 343, 231, 465, 8798, 3, 89]

# %%
expenses.sort()
expenses
# Out:
# [3, 23, 89, 231, 343, 465, 8798]

# %%
expenses.sort(reverse = True)
expenses
# Out:
# [8798, 465, 343, 231, 89, 23, 3]

# %%
basket
# Out:
# ['bread', 'butter', 'fruits', 'veggies', 'eggs']

# %%
basket.sort(reverse = True)
basket
# Out:
# ['veggies', 'fruits', 'eggs', 'butter', 'bread']

# %%
basket.sort()
basket
# Out:
# ['bread', 'butter', 'eggs', 'fruits', 'veggies']

# %%
total = basket + expenses ##Concatenation
total
# Out:
# ['bread',
#  'butter',
#  'eggs',
#  'fruits',
#  'veggies',
#  8798,
#  465,
#  343,
#  231,
#  89,
#  23,
#  3]

# %%
len(total)
# Out:
# 12

# %%
dir(total)
# Out:
# ['__add__',
#  '__class__',
#  '__class_getitem__',
#  '__contains__',
#  '__delattr__',
#  '__delitem__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__iadd__',
#  '__imul__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__mul__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__reversed__',
#  '__rmul__',
#  '__setattr__',
#  '__setitem__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'append',
#  'clear',
#  'copy',
#  'count',
#  'extend',
#  'index',
#  'insert',
#  'pop',
#  'remove',
#  'reverse',
#  'sort']

# %%
basket
# Out:
# ['bread', 'butter', 'eggs', 'fruits', 'veggies']

# %%
basket.reverse()
basket
# Out:
# ['veggies', 'fruits', 'eggs', 'butter', 'bread']

# %%
random = [4.5, 4, "John", "Wick", 9.2]
random
# Out:
# [4.5, 4, 'John', 'Wick', 9.2]

# %%
# newList = extend(random, basket)
# newList
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[258], line 1
# ----> 1 newList = extend(random, basket)
#       2 newList
#
# NameError: name 'extend' is not defined

# %% [markdown]
# ![image.png](attachment:bf6a7b77-5e17-4e22-aff5-d9ab39e2ad55.png)
#
# > Error

# %%
# newList.join(random, basket)
# newList
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[259], line 1
# ----> 1 newList.join(random, basket)
#       2 newList
#
# NameError: name 'newList' is not defined

# %% [markdown]
# ![image.png](attachment:8b1b5eb7-84c1-4ff8-8f2d-afb63dd404c7.png)
#
# > Error.

# %%
random.append([1,2,3,4,5, 'appending'])
random
# Out:
# [4.5, 4, 'John', 'Wick', 9.2, [1, 2, 3, 4, 5, 'appending']]

# %% [markdown]
# ## List Exercise
#
# ![image.png](attachment:1d0b2392-a158-4763-8742-5681a6ec0a5c.png)
#
# * Link -> https://codebasics.io/courses/python-for-beginner-and-intermediate-learners/lecture/837

# %%
avengers  = ["Iron Man", "Captain America", "Black Widow", "Hulk", "Thor", "Hawkeye"]
avengers
# Out:
# ['Iron Man', 'Captain America', 'Black Widow', 'Hulk', 'Thor', 'Hawkeye']

# %%
len(avengers)
# Out:
# 6

# %%
avengers.append("Spiderman")
avengers
# Out:
# ['Iron Man',
#  'Captain America',
#  'Black Widow',
#  'Hulk',
#  'Thor',
#  'Hawkeye',
#  'Spiderman']

# %%
avengers.insert(0, "Captain America")
avengers
# Out:
# ['Captain America',
#  'Iron Man',
#  'Black Widow',
#  'Hulk',
#  'Thor',
#  'Hawkeye',
#  'Spiderman']

# %%
avengers.remove("Thor")
avengers
# Out:
# ['Captain America', 'Iron Man', 'Black Widow', 'Hulk', 'Hawkeye', 'Spiderman']

# %%
avengers.insert(1, "Thor")
avengers
# Out:
# ['Captain America',
#  'Thor',
#  'Iron Man',
#  'Black Widow',
#  'Hulk',
#  'Hawkeye',
#  'Spiderman']

# %%
avengers = []
avengers
# Out:
# []

# %%
avengers.append("Doctor Strange")
avengers
# Out:
# ['Doctor Strange']

# %%
avengers.append("Vision")
avengers.append("Wanda")
avengers.append("Kate Bishop")
avengers.append("Ant-man")
avengers
# Out:
# ['Doctor Strange', 'Vision', 'Wanda', 'Kate Bishop', 'Ant-man']

# %%
avengers.sort()
avengers # Ant-man is the leader now.
# Out:
# ['Ant-man', 'Doctor Strange', 'Kate Bishop', 'Vision', 'Wanda']
